# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reviews = pd.read_csv('Seattle/reviews.csv')
calender = pd.read_csv('Seattle/calendar.csv')
listing = pd.read_csv('Seattle/listings.csv')

# %%
calender
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 2            241032  2016-01-06         f     NaN
# 3            241032  2016-01-07         f     NaN
# 4            241032  2016-01-08         f     NaN
# ...             ...         ...       ...     ...
# 1393565    10208623  2016-12-29         f     NaN
# 1393566    10208623  2016-12-30         f     NaN
# 1393567    10208623  2016-12-31         f     NaN
# 1393568    10208623  2017-01-01         f     NaN
# 1393569    10208623  2017-01-02         f     NaN
#
# [1393570 rows x 4 columns]

# %%
sb.countplot(data = listing, x = 'review_scores_value', color = base_color,
                order = gen_order    );

# %%
base_color = sb.color_palette()[0]  
gen_order = listing['review_scores_value'].value_counts().index

# %%
rows = listing.shape[1]
rows
# Out:
# 92

# %%
df = reviews
df
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 0         7202016  38917982  2015-07-19     28943674        Bianca
# 1         7202016  39087409  2015-07-20     32440555         Frank
# 2         7202016  39820030  2015-07-26     37722850           Ian
# 3         7202016  40813543  2015-08-02     33671805        George
# 4         7202016  41986501  2015-08-10     34959538          Ming
# ...           ...       ...         ...          ...           ...
# 84844     3624990  50436321  2015-10-12     37419458          Ryan
# 84845     3624990  51024875  2015-10-17      6933252         Linda
# 84846     3624990  51511988  2015-10-20     19543701         Jaime
# 84847     3624990  52814482  2015-11-02     24445024        Jørgen
# 84848     9727246  56429621  2015-12-13     30860360     Stephanie
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# ...

# %%
df['comments'].value_counts().reset_index()
# Out:
#                                                    index  comments
# 0      The host canceled this reservation the day bef...        57
# 1      The reservation was canceled the day before ar...        48
# 2      The host canceled this reservation 4 days befo...        22
# 3      The reservation was canceled 2 days before arr...        19
# 4      The host canceled this reservation 2 days befo...        17
# ...                                                  ...       ...
# 84131  Alexia was a great host.  She was very helpful...         1
# 84132  We enjoyed our stay at Maija's place. The neig...         1
# 84133  Hadar was very accomodating and replies to ema...         1
# 84134  William's apartment is beautifully furnished a...         1
# 84135  Clint was extremely responsive and helpful. Th...         1
#
# [84136 rows x 2 columns]

# %%
calender = pd.read_csv('Seattle/calendar.csv')
calender.head(20)
# Out:
#     listing_id        date available   price
# 0       241032  2016-01-04         t  $85.00
# 1       241032  2016-01-05         t  $85.00
# 2       241032  2016-01-06         f     NaN
# 3       241032  2016-01-07         f     NaN
# 4       241032  2016-01-08         f     NaN
# 5       241032  2016-01-09         f     NaN
# 6       241032  2016-01-10         f     NaN
# 7       241032  2016-01-11         f     NaN
# 8       241032  2016-01-12         f     NaN
# 9       241032  2016-01-13         t  $85.00
# 10      241032  2016-01-14         t  $85.00
# 11      241032  2016-01-15         f     NaN
# 12      241032  2016-01-16         f     NaN
# 13      241032  2016-01-17         f     NaN
# 14      241032  2016-01-18         t  $85.00
# 15      241032  2016-01-19         t  $85.00
# 16      241032  2016-01-20         t  $85.00
# 17      241032  2016-01-21         f     NaN
# 18      241032  2016-01-22         f     NaN
# 19      241032  2016-01-23         f     NaN

# %%
a = calender['price']
a
# Out:
# 0          85.00
# 1          85.00
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 1393565      NaN
# 1393566      NaN
# 1393567      NaN
# 1393568      NaN
# 1393569      NaN
# Name: price, Length: 1393570, dtype: object

# %%
a.count()
# Out:
# 934542

# %%
calender['price'] = calender['price'].replace({'\$':''}, regex = True)
print(calender)
# Out:
#          listing_id        date available  price
# 0            241032  2016-01-04         t  85.00
# 1            241032  2016-01-05         t  85.00
# 2            241032  2016-01-06         f    NaN
# 3            241032  2016-01-07         f    NaN
# 4            241032  2016-01-08         f    NaN
# ...             ...         ...       ...    ...
# 1393565    10208623  2016-12-29         f    NaN
# 1393566    10208623  2016-12-30         f    NaN
# 1393567    10208623  2016-12-31         f    NaN
# 1393568    10208623  2017-01-01         f    NaN
# 1393569    10208623  2017-01-02         f    NaN
#
# [1393570 rows x 4 columns]

# %%
calender
# Out:
#          listing_id        date available  price
# 0            241032  2016-01-04         t  85.00
# 1            241032  2016-01-05         t  85.00
# 2            241032  2016-01-06         f    NaN
# 3            241032  2016-01-07         f    NaN
# 4            241032  2016-01-08         f    NaN
# ...             ...         ...       ...    ...
# 1393565    10208623  2016-12-29         f    NaN
# 1393566    10208623  2016-12-30         f    NaN
# 1393567    10208623  2016-12-31         f    NaN
# 1393568    10208623  2017-01-01         f    NaN
# 1393569    10208623  2017-01-02         f    NaN
#
# [1393570 rows x 4 columns]

# %%
price = calender.dropna(subset=['price'],axis=0)

price.head()
# Out:
#     listing_id        date available  price
# 0       241032  2016-01-04         t  85.00
# 1       241032  2016-01-05         t  85.00
# 9       241032  2016-01-13         t  85.00
# 10      241032  2016-01-14         t  85.00
# 14      241032  2016-01-18         t  85.00

# %%
a = price['price'].unique()
a.shape
# Out:
# (669,)

# %%
price
# Out:
#          listing_id        date available  price
# 0            241032  2016-01-04         t  85.00
# 1            241032  2016-01-05         t  85.00
# 9            241032  2016-01-13         t  85.00
# 10           241032  2016-01-14         t  85.00
# 14           241032  2016-01-18         t  85.00
# ...             ...         ...       ...    ...
# 1393207    10208623  2016-01-06         t  87.00
# 1393208    10208623  2016-01-07         t  87.00
# 1393211    10208623  2016-01-10         t  87.00
# 1393212    10208623  2016-01-11         t  87.00
# 1393213    10208623  2016-01-12         t  87.00
#
# [934542 rows x 4 columns]

# %%
price.drop(['available'],axis=1)
# Out:
#          listing_id        date  price
# 0            241032  2016-01-04  85.00
# 1            241032  2016-01-05  85.00
# 9            241032  2016-01-13  85.00
# 10           241032  2016-01-14  85.00
# 14           241032  2016-01-18  85.00
# ...             ...         ...    ...
# 1393207    10208623  2016-01-06  87.00
# 1393208    10208623  2016-01-07  87.00
# 1393211    10208623  2016-01-10  87.00
# 1393212    10208623  2016-01-11  87.00
# 1393213    10208623  2016-01-12  87.00
#
# [934542 rows x 3 columns]

# %%
price.tail(10)
# Out:
#          listing_id        date available  price
# 1393016     9604740  2016-06-28         t  99.00
# 1393017     9604740  2016-06-29         t  99.00
# 1393018     9604740  2016-06-30         t  99.00
# 1393205    10208623  2016-01-04         t  87.00
# 1393206    10208623  2016-01-05         t  87.00
# 1393207    10208623  2016-01-06         t  87.00
# 1393208    10208623  2016-01-07         t  87.00
# 1393211    10208623  2016-01-10         t  87.00
# 1393212    10208623  2016-01-11         t  87.00
# 1393213    10208623  2016-01-12         t  87.00

# %%
filer = price[price.date == '2016-05-19']
filer
# Out:
#          listing_id        date available   price
# 136          241032  2016-05-19         t   85.00
# 501          953595  2016-05-19         t  170.00
# 1596         278830  2016-05-19         t  450.00
# 1961        5956968  2016-05-19         t  120.00
# 2326        1909058  2016-05-19         t   80.00
# ...             ...         ...       ...     ...
# 1390056     1844791  2016-05-19         t  350.00
# 1390421     6120046  2016-05-19         t  120.00
# 1390786      262764  2016-05-19         t  195.00
# 1391151     8578490  2016-05-19         t   80.00
# 1392976     9604740  2016-05-19         t   99.00
#
# [2575 rows x 4 columns]

# %%
filt = filer[filer['price']== '450.00']
filt
# Out:
#          listing_id        date available   price
# 1596         278830  2016-05-19         t  450.00
# 9261        3544550  2016-05-19         t  450.00
# 192491       790860  2016-05-19         t  450.00
# 260746      2979387  2016-05-19         t  450.00
# 649836      8373832  2016-05-19         t  450.00
# 696191      8307502  2016-05-19         t  450.00
# 1205366     4334804  2016-05-19         t  450.00
# 1327276     6586979  2016-05-19         t  450.00

# %%
filt = filer[filer['price']== '120.00']
filt.shape
# Out:
# (50, 4)

# %%
filter1 = price[price.date == '2016-01-12']
filter1
# Out:
#          listing_id        date available   price
# 373          953595  2016-01-12         t  125.00
# 1468         278830  2016-01-12         t  500.00
# 2198        1909058  2016-01-12         t   80.00
# 4388        3883392  2016-01-12         t  195.00
# 4753        8889257  2016-01-12         t   98.00
# ...             ...         ...       ...     ...
# 1391753     8101950  2016-01-12         t  359.00
# 1392118     8902327  2016-01-12         t   52.00
# 1392483    10267360  2016-01-12         t   93.00
# 1392848     9604740  2016-01-12         t   99.00
# 1393213    10208623  2016-01-12         t   87.00
#
# [2114 rows x 4 columns]

# %%
filt_1 = filter1[filter1['price'] == '500.00']
filt_1
# Out:
#          listing_id        date available   price
# 1468         278830  2016-01-12         t  500.00
# 248573      8327765  2016-01-12         t  500.00
# 589483      7388225  2016-01-12         t  500.00
# 945723      6032726  2016-01-12         t  500.00
# 1248308     8227710  2016-01-12         t  500.00

# %%
filter2 = price[price.date == '2016-01-04']
filter2
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t   85.00
# 365          953595  2016-01-04         t  125.00
# 730         3308979  2016-01-04         t  975.00
# 1460         278830  2016-01-04         t  600.00
# 2190        1909058  2016-01-04         t   80.00
# ...             ...         ...       ...     ...
# 1389920     1844791  2016-01-04         t  199.00
# 1390285     6120046  2016-01-04         t  120.00
# 1391745     8101950  2016-01-04         t  359.00
# 1392840     9604740  2016-01-04         t   99.00
# 1393205    10208623  2016-01-04         t   87.00
#
# [1735 rows x 4 columns]

# %%
filt_2 = filter2[filter2['price']== '85.00']
filt_2.shape
# Out:
# (43, 4)

# %%
listing
# Out:
#             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# ...

# %%
calender
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 2            241032  2016-01-06         f     NaN
# 3            241032  2016-01-07         f     NaN
# 4            241032  2016-01-08         f     NaN
# ...             ...         ...       ...     ...
# 1393565    10208623  2016-12-29         f     NaN
# 1393566    10208623  2016-12-30         f     NaN
# 1393567    10208623  2016-12-31         f     NaN
# 1393568    10208623  2017-01-01         f     NaN
# 1393569    10208623  2017-01-02         f     NaN
#
# [1393570 rows x 4 columns]

# %%
a = calender[['listing_id'],['date'], ]
